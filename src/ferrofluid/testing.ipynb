# %% [markdown]
# # Testing different functions in the model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import seaborn as sns
import scipy as sp

from diff_equation import *

# %%
dim_data = grab_training_data()

# %%
data_1mm = dim_data[1]

# %%
print(data_1mm)
# Out:
#     Unnamed: 0        TIME  DISTANCE
# 10          10    0.189385  0.002007
# 20          20    1.126793  0.005324
# 30          30    5.588492  0.008645
# 40          40   28.508810  0.012402
# 50          50  168.182980  0.017477
# 60          60  461.812361  0.020487

# %%
xs = torch.linspace(0, 0.03, 100)
plt.plot(xs, H(xs, 0.02))

# %%
plt.plot(xs, dH_dx(xs, 0.02))

# %%
t = 0
plt.plot(xs, dt_dx_dim(xs, 0.02, 0))

# %%
def system(x, t):
    return [dt_dx_dim(x, 0.02, 0), x]

sol = sp.integrate.odeint(dt_dx_dim, 0.02, 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sp.integrate.odeint(dt_dx_dim, 0.02, 0)
#
# File /opt/anaconda3/envs/pinns/lib/python3.12/site-packages/scipy/integrate/_odepack_py.py:244, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     241 if mu is None:
#     242     mu = -1  # changed to zero inside function call
# --> 244 dt = np.diff(t)
#     245 if not ((dt >= 0).all() or (dt <= 0).all()):
#     246     raise ValueError("The values in t must be monotonically increasing "
#     247                      "or monotonically decreasing; repeated values are "
#     248                      "allowed.")
#
# File /opt/anaconda3/envs/pinns/lib/python3.12/site-packages/numpy/lib/function_base.py:1418, in diff(a, n, axis, prepend, append)
# ...
